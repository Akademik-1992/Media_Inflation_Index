# %%
from transformers import pipeline
# загрузка и предобработка
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import openpyxl, graphviz, sklearn, shap

# https://github.com/huggingface/transformers
# обучение, загрузка по формату библиотеки, оптимизаторы
# !pip install transformers
# !pip install datasets
# !pip install umap-learn
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification, AdamW, get_scheduler
# обучение
import torch
from torch.utils.data import DataLoader
# предобработка и финальный отчет по метрикам
from sklearn import preprocessing
from sklearn.metrics import classification_report
# кластеризация
from sklearn.feature_extraction.text import CountVectorizer
import umap
from sklearn.cluster import DBSCAN
# прогресс бар
from tqdm import tqdm
# очистка кешей
import gc
# размер шрифта в графиках
import matplotlib
matplotlib.rcParams.update({'font.size': 22})

# %%
model_name = "model_f1_max=0.854261184506899"

tokenizer = AutoTokenizer.from_pretrained('ai-forever/ruBert-base')
# если есть желание дообучить лучшую модель - оставить эту строчку кода, иначе убрать
# model_name = 'sber-80(-84)'
model = AutoModelForSequenceClassification.from_pretrained(model_name, 
                                                           num_labels=2, 
                                                           output_attentions=False,
                                                           output_hidden_states=False,
                                                           ignore_mismatched_sizes=True)

# %%
df_0 = pd.read_excel('Файл_для_применения_BERT.xlsx') #, sheet_name='Инфляция'

# %%
df_0.head(3)
# Out:
#         date                                               text  \
# 0 2024-12-01  Начатые властями Киргизии в отношении «Яндекс ...
# 1 2024-12-01  По итогам первых предварительных итогов «черно...
# 2 2024-12-01  За год в России закрылось свыше 200 книжных ма...
#
#                                                 item  \
# 0                           В такси подсели проверки
# 1  «Черная пятница» прошла в соединенно-штатном р...
# 2                 В книжные магазины заглянул кризис
#
#                                     link  category             type
# 0  https://www.kommersant.ru/doc/7344142        41  Инфляция и цены
# 1  https://www.kommersant.ru/doc/7344071        41  Инфляция и цены
# 2  https://www.kommersant.ru/doc/7344021        41  Инфляция и цены

# %%
# df_1 = df_0[[df_0.type == 'Инфляция и цены']]

# %%
# df_1.head(3)

# %%
df = df_0['text']
type(df)
# Out:
# pandas.core.series.Series

# %%
df.to_csv('test.csv', index=False)

# %%
dataset = load_dataset('csv', data_files={'test': 'test.csv'})
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 393
#     })
# })

# %%
dataset = dataset.map(lambda e: tokenizer(e['text'], truncation = True, max_length=300, padding='max_length'), batched=True)
# Out:
# Map:   0%|          | 0/393 [00:00<?, ? examples/s]

# %%
# это стандартные колонки для формата пайторча, все кроме них убираем
pytorch_style_columns = ['input_ids', 'token_type_ids', 'attention_mask']  #
# убираем их из загрузчика
dataset = dataset.remove_columns(list(set(list(dataset['test'].features.keys())) - set(pytorch_style_columns)))

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 393
#     })
# })

# %%
# переврдим в формат пайторча
# сразу грузим на gpu, если есть cuda, иначе девайс стоит убрать из аргумента
dataset.set_format(type='torch', columns=pytorch_style_columns, device='cuda')

# %%
# установить 8 или больше, если более 16 гб видеопамяти
test_dataloader = DataLoader(dataset['test'], shuffle=False, batch_size=1)

# %%
len(test_dataloader)
# Out:
# 393

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %%
# np.save('classes.npy', Label_encoder.classes_)
Label_encoder = preprocessing.LabelEncoder()

# для того, чтобы восстановить кодировку целевых признаков как при обучении
Label_encoder.classes_ = np.load('classes.npy', allow_pickle=True)

# валидируем по тесту
# реальные ответы и предсказания
# true = []
preds = []
val = []

# переводим модель в режим инференса
model.eval()
# проходимся по батчам теста
for batch in tqdm(test_dataloader):
    # переносим батч на GPU
    batch = {k: v.to(device) for k, v in batch.items()}
    # без обновления параметров находим прогнозы
    with torch.no_grad():
        outputs = model(**batch)
    # получаем логиты
    logits = outputs.logits
    # из логитов прогноз
    predictions = torch.softmax(logits, dim=-1) #predictions = torch.argmax(logits, dim=-1)
#     print(round(float(predictions[0][1]),3))
    # добавляем пачки ответов и прогнозов в массивы
#     true += batch["labels"].detach().cpu().numpy().tolist()
#     preds += round(float(predictions[0][1],3))  #.detach().cpu().numpy().tolist()

    preds.append(float(predictions[0][1]))
    val.append(logits)
# ковертируем ответы и прогнозы обратно в человеко-читаемые названия классов, смотрим report по всем метрикам по каждому классу
# print(classification_report(Label_encoder.inverse_transform(true), Label_encoder.inverse_transform(preds)))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 393/393 [00:17<00:00, 23.06it/s]

# %%
preds
# Out:
# [0.010994292795658112,
#  0.9693111777305603,
#  0.010895106010138988,
#  0.39859768748283386,
#  0.8457617163658142,
#  0.7684265375137329,
#  0.009940050542354584,
#  0.8032139539718628,
#  0.8800523281097412,
#  0.006371532566845417,
#  0.9504613876342773,
#  0.9669992327690125,
#  0.9857250452041626,
#  0.6915534138679504,
#  0.02598835900425911,
#  0.6450362801551819,
#  0.9839782118797302,
#  0.8389288187026978,
#  0.15694794058799744,
#  0.9530960321426392,
#  0.9881312847137451,
#  0.9425320625305176,
#  0.8956959247589111,
#  0.9754029512405396,
#  0.00585210183635354,
#  0.06489956378936768,
#  0.8276351094245911,
#  0.1074289008975029,
#  0.9578237533569336,
#  0.9759758114814758,
#  0.9844833016395569,
#  0.3292654752731323,
#  0.9826241135597229,
#  0.43730854988098145,
#  0.08841470628976822,
#  0.9196351170539856,
#  0.016010446473956108,
#  0.006923337001353502,
#  0.9857336282730103,
#  0.9870261549949646,
#  0.010615035891532898,
#  0.008796686306595802,
#  0.9920353293418884,
#  0.886360228061676,
#  0.9859922528266907,
#  0.9371753931045532,
#  0.9534047245979309,
#  0.548741340637207,
#  0.8410810232162476,
#  0.9816657900810242,
#  0.9294130206108093,
#  0.006396722514182329,
#  0.704288125038147,
#  0.9755750894546509,
#  0.9743300080299377,
#  0.9646719694137573,
#  0.9679523706436157,
#  0.9032453894615173,
#  0.9873576164245605,
#  0.009016674011945724,
#  0.9684897661209106,
#  0.008003892377018929,
#  0.9551942944526672,
#  0.9692769050598145,
#  0.98907870054245,
#  0.006184010300785303,
#  0.005042547360062599,
#  0.013685108162462711,
#  0.0321759432554245,
#  0.08695636689662933,
#  0.10005223006010056,
#  0.02168874628841877,
#  0.8140352368354797,
#  0.18514692783355713,
#  0.01754480041563511,
#  0.11980704963207245,
#  0.9863873720169067,
#  0.6364055275917053,
#  0.20385971665382385,
#  0.9809127449989319,
#  0.030518369749188423,
#  0.2851625978946686,
#  0.9853581190109253,
#  0.33343690633773804,
#  0.9861818552017212,
#  0.7662564516067505,
#  0.007295491173863411,
#  0.976912260055542,
#  0.1696416139602661,
#  0.9702073931694031,
#  0.8113106489181519,
#  0.9793030619621277,
#  0.015286804176867008,
#  0.8780950307846069,
#  0.9697089791297913,
#  0.7208290100097656,
#  0.9855544567108154,
#  0.23302949965000153,
#  0.9845348596572876,
#  0.22437898814678192,
#  0.8137971758842468,
#  0.41101711988449097,
#  0.64228355884552,
#  0.8732333779335022,
#  0.04407099261879921,
#  0.25553008913993835,
#  0.21802431344985962,
#  0.1002945527434349,
#  0.04964974895119667,
#  0.968025267124176,
#  0.05683637037873268,
#  0.9858453273773193,
#  0.15012416243553162,
#  0.9775094985961914,
#  0.8370949625968933,
#  0.25621822476387024,
#  0.26288938522338867,
#  0.016715403646230698,
#  0.5299566388130188,
#  0.9692846536636353,
#  0.9856593012809753,
#  0.8147519826889038,
#  0.9804643392562866,
#  0.9724857807159424,
#  0.1314041018486023,
#  0.7275763750076294,
#  0.16682879626750946,
#  0.9763586521148682,
#  0.07698756456375122,
#  0.05875081568956375,
#  0.00528057711198926,
#  0.02968527376651764,
#  0.06512593477964401,
#  0.9846596717834473,
#  0.020804833620786667,
#  0.9805154800415039,
#  0.014613115228712559,
#  0.9880321025848389,
#  0.02342117764055729,
#  0.011416659690439701,
#  0.9895023107528687,
#  0.005365557968616486,
#  0.9695073366165161,
#  0.006314972415566444,
#  0.014719448983669281,
#  0.9825828075408936,
#  0.048379670828580856,
#  0.9218211770057678,
#  0.9847321510314941,
#  0.9849855899810791,
#  0.9753223657608032,
#  0.8217825889587402,
#  0.08353268355131149,
#  0.005043722223490477,
#  0.008536707609891891,
#  0.007789755705744028,
#  0.10046256333589554,
#  0.9649843573570251,
#  0.9482527375221252,
#  0.00942352507263422,
#  0.9242072701454163,
#  0.13563048839569092,
#  0.9765854477882385,
#  0.1019449457526207,
#  0.02043868415057659,
#  0.008788873441517353,
#  0.3914420008659363,
#  0.8505633473396301,
#  0.9868596196174622,
#  0.013976514339447021,
#  0.9822554588317871,
#  0.010200920514762402,
#  0.9805105328559875,
#  0.9641246199607849,
#  0.006173890549689531,
#  0.8992339372634888,
#  0.9822976589202881,
#  0.706675112247467,
#  0.48185163736343384,
#  0.21225596964359283,
#  0.0076205492950975895,
#  0.013801398687064648,
#  0.9802632927894592,
#  0.4626550078392029,
#  0.9730027318000793,
#  0.01603563129901886,
#  0.1312650442123413,
#  0.59474116563797,
#  0.026922618970274925,
#  0.9570409059524536,
#  0.006693111266940832,
#  0.9048801064491272,
#  0.84646075963974,
#  0.019979828968644142,
#  0.9686060547828674,
#  0.07285327464342117,
#  0.9859806299209595,
#  0.006782549433410168,
#  0.7179461717605591,
#  0.36735275387763977,
#  0.3418358564376831,
#  0.968003511428833,
#  0.04212115332484245,
#  0.9701262712478638,
#  0.7121434211730957,
#  0.6047880053520203,
#  0.00882395263761282,
#  0.9860413670539856,
#  0.0048005287535488605,
#  0.01905384473502636,
#  0.005206282250583172,
#  0.9712085723876953,
#  0.3836060166358948,
#  0.07902906835079193,
#  0.8707888126373291,
#  0.012219431810081005,
#  0.0165930837392807,
#  0.9606971740722656,
#  0.9693278670310974,
#  0.8213033080101013,
#  0.9853867292404175,
#  0.9697171449661255,
#  0.9825882911682129,
#  0.9876465797424316,
#  0.9826763868331909,
#  0.1413993090391159,
#  0.97350013256073,
#  0.9430468082427979,
#  0.5310606956481934,
#  0.9477783441543579,
#  0.9842551946640015,
#  0.9848129153251648,
#  0.9800337553024292,
#  0.9430468082427979,
#  0.979420006275177,
#  0.47954151034355164,
#  0.9047510027885437,
#  0.022119492292404175,
#  0.11370210349559784,
#  0.9436239004135132,
#  0.15192456543445587,
#  0.00496634328737855,
#  0.9764406085014343,
#  0.9876911640167236,
#  0.05830440670251846,
#  0.9802370667457581,
#  0.5030831694602966,
#  0.9396018981933594,
#  0.9836998581886292,
#  0.9672200679779053,
#  0.9608891010284424,
#  0.008714666590094566,
#  0.9708177447319031,
#  0.8519365787506104,
#  0.035587262362241745,
#  0.9739536046981812,
#  0.13043716549873352,
#  0.012409145012497902,
#  0.6839278936386108,
#  0.028948623687028885,
#  0.5984087586402893,
#  0.007991600781679153,
#  0.08945972472429276,
#  0.4111301600933075,
#  0.9734209775924683,
#  0.9184961915016174,
#  0.9664693474769592,
#  0.010452413000166416,
#  0.43468737602233887,
#  0.054762545973062515,
#  0.014821821823716164,
#  0.7629050612449646,
#  0.03987714275717735,
#  0.9748357534408569,
#  0.9534642696380615,
#  0.9820797443389893,
#  0.008096430450677872,
#  0.03991676867008209,
#  0.9446125626564026,
#  0.008110227063298225,
#  0.8589127063751221,
#  0.09064673632383347,
#  0.019531669095158577,
#  0.93360435962677,
#  0.10223588347434998,
#  0.9526842832565308,
#  0.8994353413581848,
#  0.5366460084915161,
#  0.7643404603004456,
#  0.9732851982116699,
#  0.03325191140174866,
#  0.008104367181658745,
#  0.05776526406407356,
#  0.925462007522583,
#  0.8349001407623291,
#  0.951521098613739,
#  0.7755303978919983,
#  0.036156170070171356,
#  0.9687927961349487,
#  0.9000043869018555,
#  0.010381120257079601,
#  0.5366460084915161,
#  0.9732851982116699,
#  0.03325191140174866,
#  0.008104367181658745,
#  0.9555086493492126,
#  0.9776393175125122,
#  0.9126847386360168,
#  0.9609390497207642,
#  0.9800900220870972,
#  0.908782422542572,
#  0.9878336191177368,
#  0.7033255100250244,
#  0.009892738424241543,
#  0.9878336191177368,
#  0.983451247215271,
#  0.014108213596045971,
#  0.1940186768770218,
#  0.009218446910381317,
#  0.2318696677684784,
#  0.0054313018918037415,
#  0.013001574203372002,
#  0.006042599678039551,
#  0.9652119874954224,
#  0.2318696677684784,
#  0.058803606778383255,
#  0.0054313018918037415,
#  0.006042599678039551,
#  0.9690563082695007,
#  0.014490146189928055,
#  0.6114954948425293,
#  0.006263147108256817,
#  0.9569549560546875,
#  0.7238756418228149,
#  0.00480469036847353,
#  0.5922406911849976,
#  0.007229303475469351,
#  0.9807178974151611,
#  0.012207793071866035,
#  0.9715689420700073,
#  0.008927624672651291,
#  0.45949381589889526,
#  0.038837406784296036,
#  0.9724580645561218,
#  0.01820974051952362,
#  0.8809278607368469,
#  0.8496236801147461,
#  0.9621343612670898,
#  0.7967754602432251,
#  0.8434319496154785,
#  0.00996843446046114,
#  0.00691649504005909,
#  0.005369473248720169,
#  0.9292204976081848,
#  0.8928771018981934,
#  0.009945598430931568,
#  0.006582016125321388,
#  0.006206910125911236,
#  0.184602752327919,
#  0.9756898880004883,
#  0.6258056163787842,
#  0.9759538173675537,
#  0.11027597635984421,
#  0.007215107325464487,
#  0.9867924451828003,
#  0.9822357892990112,
#  0.356584370136261,
#  0.9592257738113403,
#  0.5646747350692749,
#  0.023891298100352287,
#  0.004826441407203674,
#  0.8308712840080261,
#  0.19468899071216583,
#  0.9857315421104431,
#  0.11994015425443649,
#  0.1836274266242981,
#  0.960742712020874,
#  0.9096595048904419,
#  0.8116239905357361,
#  0.005558860953897238,
#  0.9811893701553345,
#  0.10060586780309677,
#  0.9857349991798401,
#  0.9789501428604126,
#  0.007653276901692152,
#  0.9806010127067566,
#  0.9902470111846924,
#  0.975274920463562,
#  0.9849243760108948,
#  0.9129061698913574,
#  0.9874815344810486,
#  0.00775973591953516,
#  0.9880896210670471]

# %%
label = []
for prob in preds:
    if prob < 0.8:
        label.append('Проинфляционный')
    elif prob > 0.8 and prob < 0.9:
        label.append('Нейтральный')
    else:
        label.append('Дезинфляционный')
pd.DataFrame(label).value_counts()
# Out:
# Проинфляционный    207
# Дезинфляционный    155
# Нейтральный         31
# dtype: int64

# %%
df_0.head(3)
# Out:
#         date                                               text  \
# 0 2024-12-01  Начатые властями Киргизии в отношении «Яндекс ...
# 1 2024-12-01  По итогам первых предварительных итогов «черно...
# 2 2024-12-01  За год в России закрылось свыше 200 книжных ма...
#
#                                                 item  \
# 0                           В такси подсели проверки
# 1  «Черная пятница» прошла в соединенно-штатном р...
# 2                 В книжные магазины заглянул кризис
#
#                                     link  category             type  \
# 0  https://www.kommersant.ru/doc/7344142        41  Инфляция и цены
# 1  https://www.kommersant.ru/doc/7344071        41  Инфляция и цены
# 2  https://www.kommersant.ru/doc/7344021        41  Инфляция и цены
#
#              label
# 0  Проинфляционный
# 1  Дезинфляционный
# 2  Проинфляционный

# %%
# df_0.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_0['label'] = label

# %%
df_0
# Out:
#           date                                               text  \
# 0   2024-12-01  Начатые властями Киргизии в отношении «Яндекс ...
# 1   2024-12-01  По итогам первых предварительных итогов «черно...
# 2   2024-12-01  За год в России закрылось свыше 200 книжных ма...
# 3   2024-12-02  Дискуссия Центробанка, правительства и крупног...
# 4   2024-12-02  «Сбер» поднял ставки по рыночным кредитам на ж...
# ..         ...                                                ...
# 388 2025-01-16  Котировки золота на мировом рынке после месячн...
# 389 2025-01-16  Индекс Московской биржи (MOEX: MOEX) в начале ...
# 390 2025-01-16  В отличие от других сегментов корпоративного ф...
# 391 2025-01-17  Сегмент автолизинга в 2024 году покажет отрица...
# 392 2025-01-17  В отличие от других сегментов корпоративного ф...
#
#                                                   item  \
# 0                             В такси подсели проверки
# 1    «Черная пятница» прошла в соединенно-штатном р...
# 2                   В книжные магазины заглянул кризис
# 3                                    ЦБ много не берет
# 4                «Сбер» последовал за ключевой ставкой
# ..                                                 ...
# 388                        Инаурумация Дональда Трампа
# 389     Индекс Мосбиржи резко вырос на открытии торгов
# 390                         Факторы отыграли срочность
# 391                               Автолизинг покатился
# 392                         Факторы отыграли срочность
#
#                                       link  category             type  \
# 0    https://www.kommersant.ru/doc/7344142        41  Инфляция и цены
# 1    https://www.kommersant.ru/doc/7344071        41  Инфляция и цены
# 2    https://www.kommersant.ru/doc/7344021        41  Инфляция и цены
# 3    https://www.kommersant.ru/doc/7309663         3  Инфляция и цены
# 4    https://www.kommersant.ru/doc/7309599         3  Инфляция и цены
# ..                                     ...       ...              ...
# 388  https://www.kommersant.ru/doc/7433478        40  Инфляция и цены
# 389  https://www.kommersant.ru/doc/7433014        40  Инфляция и цены
# 390  https://www.kommersant.ru/doc/7432786        40  Инфляция и цены
# 391  https://www.kommersant.ru/doc/7433524         4  Инфляция и цены
# 392  https://www.kommersant.ru/doc/7432786        40  Инфляция и цены
#
#                label
# 0    Проинфляционный
# 1    Дезинфляционный
# 2    Проинфляционный
# 3    Проинфляционный
# 4        Нейтральный
# ..               ...
# 388  Дезинфляционный
# 389  Дезинфляционный
# 390  Дезинфляционный
# 391  Проинфляционный
# 392  Дезинфляционный
#
# [393 rows x 7 columns]

# %%
# df_0.to_excel('Результат/Размеченные_новости_2024-12-02.xlsx')
df_0.to_excel('Результат/Размеченные_новости_новый_порог_2025-17-01.xlsx')

# %%
final = df_0['label'].groupby([df_0['date'].dt.year, df_0['date'].dt.month]).value_counts()

# %%
final
# Out:
# date  date  label
# 2024  12    Проинфляционный    163
#             Дезинфляционный    129
#             Нейтральный         25
# 2025  1     Проинфляционный     44
#             Дезинфляционный     26
#             Нейтральный          6
# Name: label, dtype: int64

# %%
final.to_excel('Результат/Оцифрованные_новости_новый_порог_2025-17-01.xlsx')

# %%
count_of_news = df_0.label.groupby([df_0['date'].dt.year, df_0['date'].dt.month]).count()

# %%
count_of_news.to_excel('Количество дек-янв.xlsx')
